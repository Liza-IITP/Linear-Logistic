# %%
import pandas as pd
import requests

# pd.read_csv(address) , pd.read_json(url/address)

# %%
re =requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
pd.DataFrame(re.json()['results']).head(10)
# Out:
#    adult                     backdrop_path         genre_ids      id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4  False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]     389
# 5  False  /m4TUa2ciEWSlk37rOsjiSIvZDXE.jpg   [16, 10751, 14]     129
# 6  False   /enNubozHn9pXi0ycTVYUWfpHZm.jpg  [18, 28, 80, 53]     155
# 7  False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 8  False  /amZavErrjrdgDwhsIdpWxHNenIx.jpg      [14, 18, 80]     497
# 9  False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
#
#   original_language                original_title  \
# 0                en      The Shawshank Redemption
# 1                en                 The Godfather
# 2                en         The Godfather Part II
# ...

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429) :
  requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}')
  temp_df = pd.DataFrame(re.json()['results'])[['id','overview','title','vote_average','popularity','vote_count','original_language','original_title']]
  df = pd.concat([df,temp_df],ignore_index=True)
df
# Out:
#            id                                           overview  \
# 0         278  Imprisoned in the 1940s for the double murder ...
# 1         238  Spanning the years 1945 to 1955, a chronicle o...
# 2         240  In the continuing saga of the Corleone crime f...
# 3         424  The true story of how businessman Oskar Schind...
# 4         389  The defense and the prosecution have rested an...
# ...       ...                                                ...
# 25675     346  A samurai answers a village's request for prot...
# 25676  157336  The adventures of a group of explorers who mak...
# 25677     769  The true story of Henry Hill, a half-Irish, ha...
# 25678   12477  In the final months of World War II, 14-year-o...
# 25679     637  A touching story of an Italian book seller of ...
#
#                           title  vote_average  popularity  vote_count  \
# 0      The Shawshank Redemption         8.712     30.2989         NaN
# ...

# %%
df.to_csv('movies.csv')

# %%
import requests

url = "https://imdb236.p.rapidapi.com/api/imdb/india/trending-tamil"

headers = {
	"x-rapidapi-key": "f3124abe7emsh09e055f6e636705p160f87jsne7771fc64afd",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

data = pd.DataFrame(response.json())[['id','primaryTitle','startYear','contentRating','numVotes','metascore','isAdult','averageRating']]
print(data.shape)
print(data.head())
# Out:
# (10, 8)
#            id     primaryTitle  startYear contentRating  numVotes metascore  \
# 0  tt28764064  Padai Thalaivan       2025          None       130      None
# 1  tt27802912              Ace       2025          None      2415      None
# 2  tt34915705   Tourist Family       2025     Not Rated      7120      None
# 3  tt23398540        Thug Life       2025          None      3178      None
# 4  tt32864330    DD Next Level       2025          None      1566      None
#
#    isAdult  averageRating
# 0    False            7.4
# 1    False            7.5
# 2    False            8.3
# 3    False            4.2
# 4    False            5.1
